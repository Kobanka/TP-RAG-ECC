# %% [markdown]
# <a href="https://colab.research.google.com/github/Kobanka/TP-RAG-ECC/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Kobanka/TP-RAG-ECC.git
# Out:
# Cloning into 'TP-RAG-ECC'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 92 (delta 48), reused 12 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 7.36 MiB | 18.25 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
